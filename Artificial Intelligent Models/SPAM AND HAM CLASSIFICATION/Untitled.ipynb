# %%
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.corpus import stopwords

# %%
st = stopwords.words('english')
print(st)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
from nltk.tokenize import word_tokenize
text = 'this is very cool'
print(word_tokenize(text))
# Out:
# ['this', 'is', 'very', 'cool']

# %%
import pandas as pd 
data = pd.read_csv('data.csv')
data
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
data['Pulse'].mean()
# Out:
# 107.46153846153847

# %%
data.shape
# Out:
# (169, 4)

# %%
data.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
data.columns
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
data.Duration
# Out:
# 0      60
# 1      60
# 2      60
# 3      45
# 4      45
#        ..
# 164    60
# 165    60
# 166    60
# 167    75
# 168    75
# Name: Duration, Length: 169, dtype: int64

# %%
data.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
data.shape
# Out:
# (169, 4)

# %%
data[data.Pulse >=120]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 22         60    130       101     300.0
# 51         80    123       146     643.1
# 54         30    136       175     238.0
# 55         60    121       146     450.7
# 58         20    153       172     226.4
# 59         45    123       152     321.0
# 80         30    159       182     319.2
# 81         45    149       169     344.0
# 85         30    151       170     300.0
# 88         45    129       103     242.0
# 94         20    150       171     127.4
# 95         20    151       168     229.4
# 97         25    152       168     244.2
# 109       210    137       184    1860.4
# 112        15    124       139     124.2
# 135        20    136       156     189.0
# 139        20    141       162     222.4
# 143        45    122       149     335.4
# 144        60    136       170     470.2
# 153        30    150       167     275.8
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
data.index
# Out:
# RangeIndex(start=0, stop=169, step=1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [1,2,3,4,5,6,7]
c= [43,23,67,43,22,56,76]
a = [10,12,43,24,56,67,43]
b =[24,34,67,42,56,32,76]

plt.ylabel('Temprature')
plt.xlabel('day')
plt.title('forcast graph')
plt.plot(x,c, label='Min_temp')
plt.plot(x,b, label='Avg_temp')
plt.plot(x,a, label = 'Max_temp')

plt.legend()

# %%
company = ['techno', 'infinix', 'samsung' , 'andriod']
revenue = [45,32,34,56]
income = [10,5,17,12]

import numpy as np

xpos  = np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.xticks(xpos, company)
plt.bar(xpos-0.2, revenue, width=0.4, label='revenue')
plt.bar(xpos+0.2, income, width=0.4, label='income')
plt.legend()

# %%
import pandas as pd
df = pd.read_csv('data.csv')
print(df.head())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df.info()
df.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
# Duration    169 non-null int64
# Pulse       169 non-null int64
# Maxpulse    169 non-null int64
# Calories    164 non-null float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130     409.1
# 1         60    117       145     479.0
# 2         60    103       135     340.0
# 3         45    109       175     282.4
# 4         45    117       148     406.0
# 5         60    102       127     300.0
# 6         60    110       136     374.0
# 7         45    104       134     253.3
# 8         30    109       133     195.1
# 9         60     98       124     269.0
# 10        60    103       147     329.3
# 11        60    100       120     250.7
# 12        60    106       128     345.3
# 13        60    104       132     379.3
# 14        60     98       123     275.0
# ...

# %%
new_df = df[['Duration', 'Calories']]
new_df.head()
# Out:
#    Duration  Calories
# 0        60     409.1
# 1        60     479.0
# 2        60     340.0
# 3        45     282.4
# 4        45     406.0

# %%
mean = new_df['Calories'].mean()
dataset = new_df.fillna({
    'Calories': mean
})
# dataset.info()
# new_df.to_csv('data1.csv')
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 2 columns):
# Duration    169 non-null int64
# Calories    169 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 2.8 KB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
dura = dataset['Duration']
pls = dataset["Calories"] 
plt.xlabel('Duration')
plt.ylabel('Calories')
plt.scatter(dura, pls, color='r' , marker='*')

# %%
from sklearn import linear_model
lm = linear_model.LinearRegression()
lm.fit(dataset[['Duration']], dataset.Calories)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_prediction = lm.predict(dataset[['Duration']])

# %%
lm.coef_
# Out:
# array([5.71626791])

# %%
lm.intercept_
# Out:
# 10.828523409715899

# %%
import pickle

with open('model_one', 'wb') as file:
    pickle.dump(lm, file)
    
with open('model_one' , 'rb') as file:
    lm = pickle.load(file)
    
    print(lm.predict([[350]]))
# Out:
# [2011.52229238]

# %%
import matplotlib.pyplot as plt
plt.xlabel('Duration (time)')
plt.ylabel('Calories (energy)')
plt.scatterter(dataset.Duration, dataset.Calories, color="red", marker='*')
plt.plot(dataset.Duration, y_prediction, color="blue")

# %%
import numpy as np 
import math
import matplotlib.pyplot as pt

x = np.array([1,2,3,4,5,6])
y = np.array([7,10,13,16,19,22])


def gradient_decent(x,y):
    learning_rate = 0.01
    m_init = 0 
    b_init = 0
    epoch = 1000
    n = len(x)
    
    for i in range(epoch):
        
        y_prediction = (m_init * x) + b_init
#   compute the cost of pridcition
        cost = (1/n) * sum([math.pow(val,2) for val in (y-y_prediction)])
        md = -(2/n) * sum(x*(y-y_prediction))
        bd = -(2/n) * sum((y-y_prediction))
        m_init = m_init - learning_rate  * md
        b_init = b_init - learning_rate * bd
        print(f'm [{m_init}] | b [{b_init}] |  cost [{cost}] | epoch = [{i}]')
    
gradient_decent(x,y)
# Out:
# m [1.19] | b [0.29] |  cost [236.5] | epoch = [0]
# m [1.9987333333333335] | b [0.4909] |  cost [110.45731666666667] | epoch = [1]
# m [2.548087888888889] | b [0.6311706666666667] |  cost [52.11371005296295] | epoch = [2]
# m [2.920985949259259] | b [0.7301811011111111] |  cost [25.103320277686706] | epoch = [3]
# m [3.1738408675728396] | b [0.8011084626407408] |  cost [12.594935926179144] | epoch = [4]
# m [3.3450315453575596] | b [0.8529174326578272] |  cost [6.7985669900239545] | epoch = [5]
# m [3.460667756313052] | b [0.8917068758296415] |  cost [4.108771991883017] | epoch = [6]
# m [3.5385123889233516] | b [0.921625995371135] |  cost [2.8568440653227456] | epoch = [7]
# m [3.5906498112739555] | b [0.9454976082390777] |  cost [2.2704552319454603] | epoch = [8]
# m [3.625301202610787] | b [0.9652421692851193] |  cost [1.9921485592962012] | epoch = [9]
# m [3.648059552635557] | b [0.9821662417166618] |  cost [1.8564818849641918] | epoch = [10]
# ...
